# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
data = pd.read_csv('https://datos.gov.co/resource/y628-5q9a.csv')
data.head(10)
# Out:
#            fecha_accidente direccion_accidente condicion_victima  \
# 0  2018-01-01T00:00:00.000         CL 87 9H 24            Peaton
# 1  2018-01-01T00:00:00.000   CLLE 119B CRA 11B            Peaton
# 2  2018-01-01T00:00:00.000          CR 8 CL 41       Acompañante
# 3  2018-01-01T00:00:00.000          CR 8 CL 41         Conductor
# 4  2018-01-01T00:00:00.000          CR 8 CL 41      Motociclista
# 5  2018-01-02T00:00:00.000   CIRCUNVALAR CR 9G       Acompañante
# 6  2018-01-02T00:00:00.000   CIRCUNVALAR CR 9G      Motociclista
# 7  2018-01-02T00:00:00.000         CL 30 CR 30         Conductor
# 8  2018-01-03T00:00:00.000     CLLE 110 CRA 52      Motociclista
# 9  2018-01-03T00:00:00.000     CLLE 110 CRA 52            Peaton
#
#   gravedad_accidente clase_accidente sexo_victima  edad_victima  \
# 0             herido       Atropello            M          57.0
# 1             herido       Atropello            F          13.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   fecha_accidente      1000 non-null   object
#  1   direccion_accidente  1000 non-null   object
#  2   condicion_victima    1000 non-null   object
#  3   gravedad_accidente   1000 non-null   object
#  4   clase_accidente      1000 non-null   object
#  5   sexo_victima         1000 non-null   object
#  6   edad_victima         1000 non-null   float64
#  7   cantidad_victimas    1000 non-null   float64
# dtypes: float64(2), object(6)
# memory usage: 62.6+ KB

# %%
data['clase_accidente'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
# Out:
# <Axes: ylabel='count'>

# %%
cross_table = pd.crosstab(data['clase_accidente'], data['gravedad_accidente'])
cross_table
cross_table.plot(kind = 'bar')
plt.show()

# %%
drivers = data[(data['condicion_victima'] == 'Conductor') | (data['condicion_victima'] == 'Motociclista')]
tabla_cruzada2 = pd.crosstab(drivers['edad_victima'], drivers['clase_accidente'])
tabla_cruzada2.plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### Hay una cantidad notable de jóvenes conductores presentes en algún tipo de accidente, mayormente en choques. ###

# %%
tabla_cruzada3 = pd.crosstab(drivers['sexo_victima'], drivers['condicion_victima'])
tabla_cruzada3.plot(kind = 'bar')
plt.show()

# %% [markdown]
# ### Hay muchos más conductores hombres que mujeres presentes en accidentes, además, las motocicletas son más propensas a estar en accidentes. ###

# %%
data['cantidad_victimas'].value_counts().plot(kind = 'pie', autopct = '%1.1f%%')
plt.show()
